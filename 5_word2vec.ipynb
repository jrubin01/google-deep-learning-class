# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# %matplotlib inline

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  f = zipfile.ZipFile(filename)
  for name in f.namelist():
    return tf.compat.as_str(f.read(name)).split()
  f.close()
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'term', 'anarchism', 'originated', 'of', 'as', 'originated', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default():

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.940846
# Nearest to that: control, shipper, breaches, hermetical, smarter, byzantines, muller, jasmuheen,
# Nearest to some: guessing, parting, transports, reconstruct, servlet, bernardi, medicines, branagh,
# Nearest to up: halide, discovering, megawati, immutable, wettest, cherry, slates, preventing,
# Nearest to zero: kabila, pectoral, conditions, lens, schemas, cog, connolly, lymphatic,
# Nearest to in: laura, pornographic, tobago, expedient, falsifiability, awk, aphasia, sar,
# Nearest to would: kinsman, imbued, alps, saviola, assassinated, physically, eli, guarneri,
# Nearest to often: formalize, armenians, exclude, wmd, wp, feelings, ills, rabba,
# Nearest to new: invisibility, thummim, plank, qazaqstan, garments, demon, science, disobeyed,
# Nearest to eight: intimidated, constitutionality, normandy, eccentric, pirated, vigor, virtually, oxen,
# Nearest to between: larry, mistresses, luna, rsted, assigned, jens, ministry, scarcity,
# Nearest to when: improper, shaky, reminiscent, mosques, pluralist, critique, loony, crichton,
# Nearest to its: babbitt, savants, superheroes, parity, fraktion, unranked, statehood, dhrystone,
# Nearest to most: resolve, estranged, diacritical, ashe, cathodes, aldebaran, bathe, tm,
# Nearest to this: abhorred, syntactic, mindedness, horatio, shmuel, higgins, observer, isotopes,
# Nearest to has: hex, viceroys, huggins, despotism, dmt, adobe, madox, yardbirds,
# Nearest to by: diamagnetism, tivoli, preceding, scrupulously, cabin, tulip, stenella, chemically,
# Average loss at step 2000: 4.359634
# Average loss at step 4000: 3.862936
# Average loss at step 6000: 3.790901
# Average loss at step 8000: 3.686769
# Average loss at step 10000: 3.612583
# Nearest to that: which, this, shipper, where, ewald, what, breaches, it,
# Nearest to some: many, parting, bernardi, these, shall, reconstruct, doubles, bangladesh,
# Nearest to up: him, halide, preventing, teaspoon, discovering, cherry, covered, speeds,
# Nearest to zero: nine, five, eight, six, seven, three, four, two,
# Nearest to in: on, of, from, magically, after, for, with, at,
# Nearest to would: will, can, could, must, may, although, broadband, mornings,
# Nearest to often: unlimited, exclude, armenians, ismail, licit, conversions, ills, outrun,
# Nearest to new: meuse, demon, nontrivial, disobeyed, invisibility, poured, thummim, scrupulously,
# Nearest to eight: nine, six, five, seven, four, three, zero, two,
# Nearest to between: official, with, larry, outlandish, from, jamaican, eugene, plein,
# Nearest to when: where, pluralist, mosques, accessed, crichton, classed, topologies, loony,
# Nearest to its: the, his, francais, guildford, their, heraclitus, choreography, levin,
# Nearest to most: resolve, universities, romanis, nasa, unimaginable, diacritical, troposphere, reproductive,
# Nearest to this: it, the, which, that, shmuel, kamchatka, a, tories,
# Nearest to has: had, have, was, is, fgm, maharashtra, sure, methylated,
# Nearest to by: was, with, insects, cardboard, been, hathor, be, diamagnetism,
# Average loss at step 12000: 3.602546
# Average loss at step 14000: 3.574800
# Average loss at step 16000: 3.411987
# Average loss at step 18000: 3.458378
# Average loss at step 20000: 3.536527
# Nearest to that: which, however, what, quotes, this, but, because, also,
# Nearest to some: many, these, several, parting, all, redshifts, bernardi, its,
# Nearest to up: him, speeds, terrain, teaspoon, preventing, halide, discovering, stupor,
# Nearest to zero: five, six, seven, three, four, nine, eight, two,
# Nearest to in: at, and, with, on, from, courtesy, for, following,
# Nearest to would: will, can, could, may, must, should, did, to,
# Nearest to often: unlimited, ismail, usually, also, which, unknown, generally, cavaliers,
# Nearest to new: scrupulously, demon, disobeyed, glycosylation, thummim, fdp, stresses, meuse,
# Nearest to eight: nine, seven, six, four, five, three, two, zero,
# Nearest to between: with, from, scarcity, jamaican, eugene, official, plein, isolates,
# Nearest to when: where, if, but, until, after, crichton, accessed, during,
# Nearest to its: their, his, the, guildford, platelets, elmo, cinderella, some,
# Nearest to most: more, universities, troposphere, resolve, absentee, pursuit, discovery, immanent,
# Nearest to this: it, which, that, what, a, belonged, the, hypoglycemia,
# Nearest to has: had, have, was, is, sure, declension, does, beryl,
# Nearest to by: were, be, been, with, through, hsieh, continuance, cil,
# Average loss at step 22000: 3.506657
# Average loss at step 24000: 3.485816
# Average loss at step 26000: 3.483270
# Average loss at step 28000: 3.482386
# Average loss at step 30000: 3.500249
# Nearest to that: which, because, however, what, this, where, ewald, but,
# Nearest to some: many, these, several, all, the, dhrystone, redshifts, any,
# Nearest to up: him, speeds, enjoys, back, terrain, preventing, teaspoon, out,
# Nearest to zero: five, seven, four, six, eight, nine, three, two,
# Nearest to in: under, on, at, of, during, from, since, courtesy,
# Nearest to would: will, could, can, may, must, should, did, might,
# Nearest to often: usually, generally, unlimited, commonly, sometimes, ismail, also, still,
# Nearest to new: disobeyed, scrupulously, kuleshov, meuse, thien, menus, classrooms, true,
# Nearest to eight: nine, seven, four, six, five, three, zero, two,
# Nearest to between: with, from, scarcity, against, isolates, pyrenees, afrika, plein,
# Nearest to when: if, where, but, until, while, after, during, was,
# Nearest to its: their, his, the, heraclitus, huldrych, cinderella, seasons, levin,
# Nearest to most: more, many, universities, troposphere, some, pursuit, discovery, very,
# Nearest to this: it, which, what, fulcher, that, maynooth, belonged, tories,
# Nearest to has: had, have, is, was, fgm, sure, does, beryl,
# Nearest to by: under, were, in, with, was, wahhab, universite, continuance,
# Average loss at step 32000: 3.501143
# Average loss at step 34000: 3.493646
# Average loss at step 36000: 3.456980
# Average loss at step 38000: 3.298856
# Average loss at step 40000: 3.425818
# Nearest to that: which, however, what, because, this, quotes, who, infanta,
# Nearest to some: many, these, several, any, redshifts, this, the, those,
# Nearest to up: him, out, them, back, speeds, enjoys, quiz, preventing,
# Nearest to zero: seven, five, nine, six, eight, three, four, two,
# Nearest to in: during, for, of, intercultural, from, hemispheric, at, on,
# Nearest to would: can, will, could, may, must, should, might, did,
# Nearest to often: usually, generally, commonly, also, sometimes, unlimited, still, ismail,
# Nearest to new: scrupulously, release, alvin, disobeyed, kuleshov, particular, toynbee, rapid,
# Nearest to eight: nine, seven, five, six, four, three, zero, two,
# Nearest to between: with, from, scarcity, afrika, pyrenees, auditor, isolates, plein,
# Nearest to when: if, where, while, until, before, after, as, was,
# Nearest to its: their, his, her, the, elmo, heraclitus, cinderella, huldrych,
# Nearest to most: more, hindu, universities, troposphere, less, many, liturgy, iib,
# Nearest to this: which, it, that, the, what, some, mandalay, fulcher,
# Nearest to has: had, have, was, is, having, collation, declension, lycopene,
# Nearest to by: be, through, personas, when, continuance, tivoli, dimmer, dung,
# Average loss at step 42000: 3.433470
# Average loss at step 44000: 3.452524
# Average loss at step 46000: 3.450858
# Average loss at step 48000: 3.352751
# Average loss at step 50000: 3.382036
# Nearest to that: which, however, what, because, quotes, where, ewald, encrypt,
# Nearest to some: many, several, these, the, various, any, their, both,
# Nearest to up: him, out, them, back, down, enjoys, speeds, stupor,
# Nearest to zero: seven, five, eight, six, four, nine, three, two,
# Nearest to in: during, on, of, from, within, under, among, since,
# Nearest to would: could, will, can, may, must, should, might, did,
# Nearest to often: generally, usually, commonly, sometimes, also, now, still, unlimited,
# Nearest to new: territorial, particular, scrupulously, satrapy, rapid, instrumentalist, hymns, kuleshov,
# Nearest to eight: six, seven, nine, four, five, three, zero, two,
# Nearest to between: with, from, scarcity, isolates, auditor, in, against, nabla,
# Nearest to when: if, while, after, until, where, before, during, however,
# Nearest to its: their, his, the, her, heraclitus, ferrell, your, guildford,
# Nearest to most: more, many, less, some, iib, among, hindu, sparks,
# Nearest to this: which, it, the, fulcher, what, heliogabalus, another, fined,
# Nearest to has: had, have, is, was, fgm, having, sure, collation,
# Nearest to by: through, was, hathor, continuance, cil, in, under, been,
# Average loss at step 52000: 3.436071
# Average loss at step 54000: 3.426695
# Average loss at step 56000: 3.439928
# Average loss at step 58000: 3.394843
# Average loss at step 60000: 3.393144
# Nearest to that: which, what, however, this, excellent, it, where, ewald,
# Nearest to some: many, several, these, various, any, all, most, this,
# Nearest to up: out, him, them, back, down, enjoys, stupor, slates,
# Nearest to zero: five, four, eight, seven, six, nine, three, two,
# Nearest to in: during, within, among, at, near, between, including, on,
# Nearest to would: could, will, can, may, must, should, might, did,
# Nearest to often: usually, generally, sometimes, commonly, also, now, still, typically,
# Nearest to new: particular, rapid, menus, scrupulously, territorial, prestigious, satrapy, thien,
# Nearest to eight: six, seven, four, nine, five, three, zero, one,
# Nearest to between: with, from, scarcity, among, in, within, afrika, segregation,
# Nearest to when: if, before, while, after, although, where, during, because,
# Nearest to its: their, his, the, her, your, cinderella, elmo, guildford,
# Nearest to most: more, many, some, use, among, habitations, earliest, indicating,
# Nearest to this: it, which, there, what, that, some, the, a,
# Nearest to has: had, have, was, is, having, duane, lycopene, fgm,
# Nearest to by: through, cil, was, hathor, hsieh, dickens, masamune, under,
# Average loss at step 62000: 3.239404
# Average loss at step 64000: 3.255988
# Average loss at step 66000: 3.401949
# Average loss at step 68000: 3.393414
# Average loss at step 70000: 3.361886
# Nearest to that: which, what, however, this, but, because, visionaries, excellent,
# Nearest to some: many, several, these, all, those, most, various, freude,
# Nearest to up: out, them, him, down, back, enjoys, off, away,
# Nearest to zero: five, eight, four, six, seven, nine, three, two,
# Nearest to in: during, among, on, within, since, for, of, until,
# Nearest to would: will, could, may, can, must, should, might, cannot,
# Nearest to often: generally, usually, sometimes, commonly, frequently, now, typically, also,
# Nearest to new: prestigious, particular, menus, scrupulously, satrapy, territorial, donkey, disobeyed,
# Nearest to eight: nine, six, seven, four, five, zero, three, two,
# Nearest to between: with, scarcity, from, among, within, auditor, afrika, in,
# Nearest to when: if, before, while, where, however, after, though, because,
# Nearest to its: their, his, the, her, your, elmo, whose, himalayan,
# Nearest to most: more, many, some, very, less, among, indicating, use,
# Nearest to this: it, which, the, that, another, there, fulcher, similar,
# Nearest to has: had, have, was, is, having, since, collation, duane,
# Nearest to by: through, continuance, using, hetzel, hsieh, caius, under, be,
# Average loss at step 72000: 3.363277
# Average loss at step 74000: 3.350671
# Average loss at step 76000: 3.317330
# Average loss at step 78000: 3.348448
# Average loss at step 80000: 3.375589
# Nearest to that: which, however, where, quotes, what, because, this, ewald,
# Nearest to some: many, several, these, most, both, any, various, freude,
# Nearest to up: out, down, them, him, off, back, enjoys, binocular,
# Nearest to zero: five, seven, four, six, eight, three, nine, two,
# Nearest to in: during, within, on, under, until, at, of, around,
# Nearest to would: will, could, may, should, can, must, might, cannot,
# Nearest to often: sometimes, usually, generally, commonly, typically, frequently, now, still,
# Nearest to new: satrapy, disobeyed, prestigious, particular, kuleshov, great, usual, subsequent,
# Nearest to eight: nine, six, seven, five, four, three, zero, two,
# Nearest to between: with, among, within, from, scarcity, over, in, isolates,
# Nearest to when: if, before, while, after, during, though, where, until,
# Nearest to its: their, his, her, the, your, guildford, islander, elmo,
# Nearest to most: more, many, some, among, very, less, indicating, macon,
# Nearest to this: which, it, itself, the, another, there, what, romanized,
# Nearest to has: had, have, is, was, since, having, lycopene, wtc,
# Nearest to by: through, when, continuance, under, hetzel, hsieh, albany, pequod,
# Average loss at step 82000: 3.407657
# Average loss at step 84000: 3.410485
# Average loss at step 86000: 3.386722
# Average loss at step 88000: 3.350448
# Average loss at step 90000: 3.364209
# Nearest to that: which, however, what, masons, where, quotes, but, infanta,
# Nearest to some: many, several, these, any, this, certain, most, those,
# Nearest to up: out, down, them, off, him, back, away, enjoys,
# Nearest to zero: five, seven, eight, nine, six, four, three, two,
# Nearest to in: during, within, under, until, near, of, around, between,
# Nearest to would: could, will, may, should, can, must, might, cannot,
# Nearest to often: generally, usually, sometimes, commonly, typically, frequently, now, also,
# Nearest to new: particular, kuleshov, great, satrapy, specific, scrupulously, mexica, disobeyed,
# Nearest to eight: seven, six, five, nine, four, three, zero, two,
# Nearest to between: with, within, among, scarcity, from, in, through, over,
# Nearest to when: before, if, while, where, after, until, since, though,
# Nearest to its: their, his, her, the, your, ester, our, whose,
# Nearest to most: more, many, among, some, less, use, macon, particularly,
# Nearest to this: it, which, some, the, another, exerted, itself, fulcher,
# Nearest to has: had, have, is, was, having, since, includes, collation,
# Nearest to by: through, hetzel, for, under, hsieh, during, tivoli, continuance,
# Average loss at step 92000: 3.396153
# Average loss at step 94000: 3.254820
# Average loss at step 96000: 3.355844
# Average loss at step 98000: 3.246805
# Average loss at step 100000: 3.356152
# Nearest to that: which, however, what, because, this, quotes, where, visionaries,
# Nearest to some: many, several, these, any, all, this, those, various,
# Nearest to up: out, down, off, them, him, back, enjoys, away,
# Nearest to zero: five, eight, seven, four, six, nine, three, two,
# Nearest to in: during, within, from, on, under, at, until, near,
# Nearest to would: will, could, can, may, should, might, must, cannot,
# Nearest to often: usually, generally, sometimes, commonly, frequently, typically, rarely, now,
# Nearest to new: kuleshov, specific, different, particular, satrapy, revere, luck, menus,
# Nearest to eight: seven, nine, six, five, four, three, zero, two,
# Nearest to between: with, within, among, from, over, auditor, scarcity, nabla,
# Nearest to when: if, before, while, where, after, because, although, though,
# Nearest to its: their, his, her, the, your, whose, cum, ester,
# Nearest to most: more, less, among, particularly, very, vividly, because, many,
# Nearest to this: which, it, itself, some, what, he, that, another,
# Nearest to has: had, have, is, since, was, having, collation, wtc,
# Nearest to by: through, continuance, pequod, under, when, tivoli, hetzel, including,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to Word2Vec is called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %% [markdown]
# ### Switch to CBOW model (just reverse labels)

# %%
data_index = 0
print('data:', [reverse_dictionary[di] for di in data[:8]])
for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    labels, batch = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch.reshape(8)])
    print('    labels:', [reverse_dictionary[li] for li in labels])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['as', 'anarchism', 'originated', 'a', 'as', 'term', 'of', 'a']
#     labels: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['originated', 'a', 'term', 'anarchism', 'term', 'of', 'as', 'originated']
#     labels: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_labels, batch_data = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data.reshape(batch_size), train_labels : batch_labels.reshape(batch_size, 1)}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.864043
# Nearest to that: normalize, johnny, suzhou, trade, prev, machine, lopez, monsoons,
# Nearest to some: ecma, perkins, interpersonal, waist, avery, sergei, praetorian, footballers,
# Nearest to up: disturb, midcourse, funeral, laboratories, thicknesses, olmec, martov, dropouts,
# Nearest to zero: reinforced, wgn, overhead, silla, mailbox, matejko, dunk, serfdom,
# Nearest to in: ethnological, py, named, stu, aeolian, hander, mythographers, spines,
# Nearest to would: hood, downer, willis, quadrants, filename, guinean, messe, aeolus,
# Nearest to often: fracturing, transmutations, traditionally, exchanges, neoconservative, discount, bey, stuffing,
# Nearest to new: concerts, swann, symbols, carnatic, refining, reggae, peg, jamil,
# Nearest to eight: situation, ruben, bruton, witches, plethora, derry, pasquale, articulate,
# Nearest to between: formless, desmond, efron, skynyrd, schindler, cracked, ionizing, classroom,
# Nearest to when: kista, handicaps, cayuga, knowingly, igg, kings, plundering, crates,
# Nearest to its: tennant, hazlitt, maldives, thinking, flowery, coffin, scholar, marsden,
# Nearest to most: ported, covariant, consortium, unionist, bius, bittering, commemorative, parerga,
# Nearest to this: wellington, gershwin, magellan, husky, zines, glc, copacabana, vil,
# Nearest to has: countercult, nukem, harms, skew, winnipeg, residues, gmc, deficient,
# Nearest to by: pounds, advancing, buren, diarrhea, border, deprive, iamblichus, mattered,
# Average loss at step 2000: 4.512006
# Average loss at step 4000: 4.120323
# Average loss at step 6000: 3.924021
# Average loss at step 8000: 3.925061
# Average loss at step 10000: 3.887126
# Nearest to that: lipid, rp, he, it, which, not, hurrians, monorails,
# Nearest to some: rcs, ecma, sprang, lingual, bidirectional, fun, muon, epistemology,
# Nearest to up: thicknesses, dropouts, disturb, midcourse, honors, virtue, hyatt, olmec,
# Nearest to zero: six, three, five, two, eight, four, nine, seven,
# Nearest to in: of, from, by, and, kitchens, sociopathic, as, at,
# Nearest to would: speedway, to, hood, nasrallah, whitewater, tomorrowland, irc, can,
# Nearest to often: airborne, traditionally, astronautica, bey, kabbalah, fracturing, microchips, sometimes,
# Nearest to new: carnatic, mandaic, economic, edi, mandelstam, symbols, condominium, delocalised,
# Nearest to eight: nine, seven, six, four, three, five, zero, one,
# Nearest to between: schindler, skynyrd, efron, cracked, formless, gaeilge, transl, expansions,
# Nearest to when: cayuga, hizbullah, handicaps, asin, lung, buckwheat, paralipomena, heavenly,
# Nearest to its: hazlitt, normal, kuznetsov, ashore, justicia, pied, matriculation, torr,
# Nearest to most: parerga, consortium, elect, digs, tta, overriding, lutetium, repetition,
# Nearest to this: it, the, cramped, an, fog, sabotage, gamers, husky,
# Nearest to has: had, have, compartment, is, mutagenesis, realities, mcguire, newtonian,
# Nearest to by: in, and, javelin, angelo, as, roma, with, suffer,
# Average loss at step 12000: 3.878952
# Average loss at step 14000: 3.839862
# Average loss at step 16000: 3.743276
# Average loss at step 18000: 3.817459
# Average loss at step 20000: 3.792530
# Nearest to that: which, lipid, this, it, not, when, then, apparent,
# Nearest to some: many, these, all, sprang, other, their, hard, tempore,
# Nearest to up: thicknesses, dropouts, nail, biologists, dirham, flight, you, virtue,
# Nearest to zero: six, five, four, seven, three, eight, two, nine,
# Nearest to in: from, by, at, of, during, since, defector, and,
# Nearest to would: can, could, may, will, to, did, whitewater, liverpool,
# Nearest to often: sometimes, not, airborne, enix, traditionally, votive, astronautica, atmospheric,
# Nearest to new: theogony, rameses, kung, headquarters, literary, contemptuous, enfants, concerts,
# Nearest to eight: seven, nine, four, six, five, three, zero, two,
# Nearest to between: with, skynyrd, gaeilge, schindler, verily, emcee, cola, lionel,
# Nearest to when: asin, paralipomena, that, secaucus, lung, if, heavenly, ratifies,
# Nearest to its: their, the, his, pitaka, sarabande, terrorist, effected, normal,
# Nearest to most: many, best, dianne, some, parerga, colts, identifiable, cassius,
# Nearest to this: it, that, the, which, parentage, kauravas, mpaa, zx,
# Nearest to has: had, have, is, mutagenesis, newtonian, realities, credible, psychometrics,
# Nearest to by: who, in, from, and, as, with, hegemony, kiel,
# Average loss at step 22000: 3.728950
# Average loss at step 24000: 3.790788
# Average loss at step 26000: 3.634463
# Average loss at step 28000: 3.591100
# Average loss at step 30000: 3.631176
# Nearest to that: which, this, when, but, it, however, not, afrobeat,
# Nearest to some: many, these, all, other, several, encroaching, most, tools,
# Nearest to up: dropouts, thicknesses, katha, hyatt, then, back, nail, disturb,
# Nearest to zero: five, three, four, two, seven, six, eight, nine,
# Nearest to in: from, pp, on, at, and, hipparchus, nhs, four,
# Nearest to would: can, could, may, will, to, did, cannot, should,
# Nearest to often: sometimes, airborne, traditionally, not, heretics, commonly, ya, which,
# Nearest to new: enfants, adas, rameses, theogony, sings, contemptuous, racehorse, mont,
# Nearest to eight: seven, six, nine, three, five, four, one, zero,
# Nearest to between: with, skynyrd, cola, apostle, lagrand, footlights, ionizing, into,
# Nearest to when: that, if, after, paralipomena, offense, asin, heavenly, where,
# Nearest to its: their, the, his, pitaka, transboundary, emotion, enthalpy, rips,
# Nearest to most: best, many, some, parerga, more, dianne, tremble, neurons,
# Nearest to this: it, that, what, which, garbled, an, kauravas, integrin,
# Nearest to has: had, have, is, was, succulent, newtonian, compartment, agi,
# Nearest to by: photorealistic, nucleotide, he, backspace, which, comrade, ducts, who,
# Average loss at step 32000: 3.665973
# Average loss at step 34000: 3.750527
# Average loss at step 36000: 3.684902
# Average loss at step 38000: 3.714016
# Average loss at step 40000: 3.670455
# Nearest to that: which, it, however, this, if, able, axillary, although,
# Nearest to some: many, these, all, most, other, several, any, the,
# Nearest to up: back, then, calculated, katha, thicknesses, out, nail, funeral,
# Nearest to zero: five, two, three, four, nine, six, eight, one,
# Nearest to in: since, during, of, portions, moderate, yugoslavian, slaughter, coincidences,
# Nearest to would: may, could, can, will, did, cannot, should, to,
# Nearest to often: sometimes, commonly, not, traditionally, airborne, frequently, usually, generally,
# Nearest to new: housewives, harsh, feng, contemptuous, racehorse, gibraltar, styling, rameses,
# Nearest to eight: seven, six, nine, four, five, three, two, zero,
# Nearest to between: with, hpv, skynyrd, atman, rg, cola, ionizing, leonardo,
# Nearest to when: if, where, paralipomena, after, that, cayuga, ambrose, secaucus,
# Nearest to its: their, the, her, his, this, a, erv, evacuated,
# Nearest to most: many, some, more, best, trajectory, all, nz, tremble,
# Nearest to this: it, which, the, an, that, its, sabotage, kauravas,
# Nearest to has: had, have, is, was, coyotes, telecommunication, can, newtonian,
# Nearest to by: comrade, transcribed, that, tertullian, huey, tok, have, schottenheimer,
# Average loss at step 42000: 3.675021
# Average loss at step 44000: 3.710238
# Average loss at step 46000: 3.673872
# Average loss at step 48000: 3.744623
# Average loss at step 50000: 3.650204
# Nearest to that: which, when, about, but, where, this, it, if,
# Nearest to some: many, these, all, several, any, other, various, the,
# Nearest to up: back, katha, thummim, calculated, funeral, thicknesses, nail, then,
# Nearest to zero: six, five, seven, two, three, four, eight, nine,
# Nearest to in: during, on, of, between, from, at, by, and,
# Nearest to would: will, could, may, can, did, might, to, should,
# Nearest to often: sometimes, commonly, not, generally, usually, traditionally, still, frequently,
# Nearest to new: contemptuous, gibraltar, juniper, til, pies, rameses, lessen, cottages,
# Nearest to eight: seven, six, nine, five, four, one, three, two,
# Nearest to between: with, in, from, of, jona, into, ionizing, phallic,
# Nearest to when: if, where, that, before, but, then, after, because,
# Nearest to its: their, his, her, the, hokku, pitaka, evacuated, this,
# Nearest to most: many, more, cassius, very, among, some, tremble, position,
# Nearest to this: which, it, kauravas, that, an, parentage, the, another,
# Nearest to has: had, have, is, was, since, newtonian, having, kneel,
# Nearest to by: with, who, in, for, under, kiel, as, and,
# Average loss at step 52000: 3.666449
# Average loss at step 54000: 3.756379
# Average loss at step 56000: 3.732848
# Average loss at step 58000: 3.660395
# Average loss at step 60000: 3.719106
# Nearest to that: which, what, this, when, also, about, although, where,
# Nearest to some: many, these, several, all, various, twelve, strachey, any,
# Nearest to up: off, back, him, them, out, thicknesses, calculated, cer,
# Nearest to zero: five, four, three, two, six, eight, seven, nine,
# Nearest to in: during, between, of, since, and, when, from, lynched,
# Nearest to would: will, can, could, may, did, must, might, does,
# Nearest to often: sometimes, generally, commonly, traditionally, usually, still, frequently, also,
# Nearest to new: contemptuous, pies, dielectric, expectancy, cottages, gibraltar, kit, gregers,
# Nearest to eight: seven, nine, six, four, three, five, zero, one,
# Nearest to between: with, in, of, cola, from, planks, frustrating, coaching,
# Nearest to when: if, where, because, then, before, but, that, although,
# Nearest to its: their, his, the, her, this, pied, evacuated, tack,
# Nearest to most: many, among, cassius, more, best, fontana, inanna, hezbollah,
# Nearest to this: which, it, another, a, that, an, kauravas, any,
# Nearest to has: had, have, is, was, kneel, ascendant, having, tombs,
# Nearest to by: hamas, mock, usually, personally, provence, vg, for, peptidoglycan,
# Average loss at step 62000: 3.696059
# Average loss at step 64000: 3.718328
# Average loss at step 66000: 3.533352
# Average loss at step 68000: 3.491984
# Average loss at step 70000: 3.682412
# Nearest to that: which, this, it, although, about, where, when, however,
# Nearest to some: many, several, these, various, their, other, different, all,
# Nearest to up: back, him, off, calculated, them, cer, out, unwanted,
# Nearest to zero: five, four, six, seven, three, eight, two, one,
# Nearest to in: since, on, of, until, during, librarians, from, and,
# Nearest to would: will, could, may, can, must, did, should, might,
# Nearest to often: sometimes, usually, commonly, generally, being, traditionally, typically, still,
# Nearest to new: grenadines, pies, gibraltar, contemptuous, fax, lions, disproportionately, literary,
# Nearest to eight: nine, seven, six, four, five, three, zero, one,
# Nearest to between: with, from, in, cola, predictable, marge, rg, fein,
# Nearest to when: if, before, where, then, while, rescues, however, after,
# Nearest to its: their, his, her, the, pied, hokku, evacuated, yearning,
# Nearest to most: more, many, best, very, unbiased, among, shakti, richly,
# Nearest to this: it, that, the, kauravas, which, another, an, a,
# Nearest to has: had, have, is, was, deploying, having, kneel, mcclory,
# Nearest to by: ducts, at, with, astounding, provence, tertullian, classicism, mccann,
# Average loss at step 72000: 3.601878
# Average loss at step 74000: 3.697522
# Average loss at step 76000: 3.602304
# Average loss at step 78000: 3.729857
# Average loss at step 80000: 3.651128
# Nearest to that: which, this, linnaean, already, also, nmt, however, baggins,
# Nearest to some: many, several, various, these, all, other, twelve, different,
# Nearest to up: off, him, back, mjt, calculated, uploaded, out, katha,
# Nearest to zero: five, two, eight, seven, four, three, six, nine,
# Nearest to in: during, since, between, on, acrylic, optimally, tougher, until,
# Nearest to would: will, could, must, may, can, might, did, should,
# Nearest to often: sometimes, usually, commonly, generally, still, also, typically, traditionally,
# Nearest to new: disproportionately, york, literary, rameses, ghats, neat, aswan, speedily,
# Nearest to eight: seven, nine, six, four, five, zero, one, three,
# Nearest to between: with, in, from, phallic, masterpieces, over, into, marquee,
# Nearest to when: where, while, before, eventually, however, if, although, then,
# Nearest to its: their, his, the, pied, her, tack, hokku, this,
# Nearest to most: more, best, aswan, among, richly, inanna, many, unbiased,
# Nearest to this: it, which, that, another, folders, every, reznor, an,
# Nearest to has: had, have, is, sulfides, since, kneel, was, having,
# Nearest to by: with, ducts, hamas, lynched, irt, roux, wrapper, who,
# Average loss at step 82000: 3.689333
# Average loss at step 84000: 3.639062
# Average loss at step 86000: 3.629091
# Average loss at step 88000: 3.573494
# Average loss at step 90000: 3.578478
# Nearest to that: which, this, also, however, what, although, launchers, afrobeat,
# Nearest to some: many, several, all, both, these, numerous, various, other,
# Nearest to up: off, back, them, out, governed, illuminati, him, calculated,
# Nearest to zero: six, two, eight, nine, three, one, five, four,
# Nearest to in: until, since, on, during, from, after, tra, druidry,
# Nearest to would: will, could, can, did, may, should, must, does,
# Nearest to often: sometimes, usually, generally, commonly, still, frequently, also, typically,
# Nearest to new: york, literary, kleene, disproportionately, klondike, faintly, presidents, aswan,
# Nearest to eight: seven, six, nine, three, four, five, one, zero,
# Nearest to between: with, marquee, planks, through, flawed, phallic, terrains, transceiver,
# Nearest to when: while, because, where, if, although, before, since, however,
# Nearest to its: their, his, the, her, pied, monarchs, excavating, an,
# Nearest to most: more, best, first, some, preprint, less, many, among,
# Nearest to this: which, another, it, that, the, a, folders, fifths,
# Nearest to has: had, have, is, having, was, tombs, since, kneel,
# Nearest to by: and, who, backspace, in, UNK, monck, has, tabasco,
# Average loss at step 92000: 3.655170
# Average loss at step 94000: 3.681298
# Average loss at step 96000: 3.630590
# Average loss at step 98000: 3.703505
# Average loss at step 100000: 3.666959
# Nearest to that: which, when, however, mentality, nmt, although, veterinarian, nir,
# Nearest to some: many, several, various, these, all, numerous, most, others,
# Nearest to up: off, back, dropouts, out, katha, governed, polskiej, bedi,
# Nearest to zero: six, four, five, seven, eight, two, three, nine,
# Nearest to in: during, within, until, since, of, between, and, from,
# Nearest to would: could, will, can, should, may, might, must, did,
# Nearest to often: sometimes, usually, generally, commonly, still, frequently, typically, widely,
# Nearest to new: york, disproportionately, pressurized, literary, serenity, canopy, abet, walser,
# Nearest to eight: six, seven, nine, four, five, three, zero, one,
# Nearest to between: with, flawed, through, from, in, down, marquee, masterpieces,
# Nearest to when: where, if, while, although, before, because, though, that,
# Nearest to its: their, his, the, her, pied, liable, s, tack,
# Nearest to most: many, more, best, some, vitoria, preprint, unbiased, because,
# Nearest to this: it, which, another, kauravas, an, homomorphism, friendly, what,
# Nearest to has: had, have, is, having, was, ascendant, missed, tombs,
# Nearest to by: who, monck, quechua, statistician, paul, dravidians, reawakened, backspace,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
